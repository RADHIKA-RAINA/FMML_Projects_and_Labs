# %% [markdown]
# <a href="https://colab.research.google.com/github/RADHIKA-RAINA/FMML_Projects_and_Labs/blob/main/Copy_of_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 15:51:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   206MB/s    in 0.3s
#
# 2025-03-16 15:51:29 (206 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9313    1210.2429v1  Android and Facebook provide third-party appli...    cs
# 11360  1511.02124v2  We introduce a globally-convergent algorithm f...  stat
# 37978   0909.2904v2  Structural equation models and Bayesian networ...  stat
# 8627   1708.00197v1  Conventional video segmentation methods often ...    cs
# 10237  1803.00162v1  The Iterated Prisoner's Dilemma has guided res...    cs
# ...             ...                                                ...   ...
# 34048   1309.1536v2  We show that the Zipf's law for Chinese charac...    cs
# 19767   1207.1375v1  The Bayesian Logic (BLOG) language was recentl...    cs
# 17752  1802.07117v1  Chatbots, taking advantage of the success of t...    cs
# 24949  1501.02876v5  We present a state-of-the-art image recognitio...    cs
# 4595    1301.0598v1  We develop a closed form asymptotic formula to...    cs
#
#                                                    title  year  \
# 9313   Mining Permission Request Patterns from Androi...  2012
# 11360         Barrier Frank-Wolfe for Marginal Inference  2015
# 37978  Computing p-values of LiNGAM outputs via Multi...  2009
# 8627    Video Object Segmentation with Re-identification  2017
# 10237  Towards Cooperation in Sequential Prisoner's D...  2018
# ...                                                  ...   ...
# 34048     Rank-frequency relation for Chinese characters  2013
# 19767                       Nonparametric Bayesian Logic  2012
# 17752  Combining Textual Content and Structure to Imp...  2018
# 24949           Deep Image: Scaling up Image Recognition  2015
# 4595   Asymptotic Model Selection for Naive Bayesian ...  2012
#
#                                                 keywords
# 9313   [applications, potentially, sensitive, operati...
# 11360  [introduce, convergent, algorithm, optimizing,...
# 37978  [structural, relationships, continuous, variab...
# 8627   [conventional, segmentation, continuity, propa...
# 10237  [prisoners, distinguishes, cooperate, prisoner...
# ...                                                  ...
# 34048  [characters, perfectly, sufficiently, differen...
# 19767  [developed, probability, important, including,...
# 17752  [advantage, messaging, artificial, intelligenc...
# 24949  [recognition, developed, components, supercomp...
# 4595   [asymptotic, likelihood, generally, statistica...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9313     [applications, potentially, sensitive, operati...
# 11360    [introduce, convergent, algorithm, optimizing,...
# 37978    [structural, relationships, continuous, variab...
# 8627     [conventional, segmentation, continuity, propa...
# 10237    [prisoners, distinguishes, cooperate, prisoner...
#                                ...
# 36880    [description, representing, knowledge, applica...
# 1792     [decompositions, framework, decomposes, sequen...
# 31177    [intraoperative, coherence, tomography, increa...
# 12045    [conditional, discrimination, discrimination, ...
# 21907    [stochastic, representing, community, structur...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8712 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c5083459-54de-4c24-a292-0738b8d6d94a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5083459-54de-4c24-a292-0738b8d6d94a")) {                    Plotly.newPlot(                        "c5083459-54de-4c24-a292-0738b8d6d94a",                        [{"x":["sensitive","demonstrate","applications","identified","stability","requested","overlapping","application","typicality","structure","satisfaction","potentially","understand","operations","platforms","permissions","factorization","suggesting","indicative","reputation","permission","simplifying","empirically","increased","unbounded","relaxation","inference","objective","posteriori","optimality","introduce","optimizing","theoretically","instances","variational","reweighted","conditional","algorithms","gradients","algorithm","synthetic","convergent","consistency","artificial","multiscale","experiments","hypothesis","relationships","confidence","directions","important","probability","variables","bootstrap","asymptotic","reliability","structural","computing","procedure","conducted","statistical","continuous","formulate","identification","assumption","inability","segmentation","conventional","effective","propagation","retrieves","performance","propagate","iteratively","displacement","challenge","continuity","mechanism","specifically","correspond","temporally","synthesizes","detection","adaptively","multiagent","reinforcement","distinguishes","sequential","cooperative","opponents","evolution","exploitative","prisoners","aforementioned","cooperate","cooperation","strategies","reflecting","exploited","experimental","gathering","sequences","effectiveness","demonstrated","characteristics","investigates","representative","different","passively","collected","opportunities","formalize","prediction","contextual","accompanied","retweeting","experiment","normative","following","aggregating","experience","adversely","followers","communitys","stationary","representing","comparison","containing","declarative","programming","knowledge","generators","abductive","substitution","approaches","semantics","combinatorial","solutions","representation","constraint","parameter","regularization","uncertainty","perspective","practitioner","operational","propagates","optimization","pessimistic","generalization","depending","reasonable","associated","theoretical","optimistic","practitioners","predictive","wasserstein","convergence","generative","penalizes","enforcing","invention","deviation","preferable","lipschitz","adversarial","supported","distribution","functions","arguments","augmenting","empirical","established","transform","denoising","therefore","perception","information","similarity","transfers","perceptual","promising","arrangement","framework","extracted","invariant","similarities","instability","differences","descriptions","qualities","connected","prominent","resulting","skeletons","curvature","viewpoint","smoothing","traditional"],"y":[56,575,421,44,35,3,21,239,2,339,17,51,52,67,27,3,35,16,8,4,2,7,72,35,5,29,238,143,10,22,343,62,46,105,52,4,107,592,30,802,130,7,59,134,10,595,57,71,36,47,370,173,120,4,18,32,73,137,114,79,155,111,68,100,71,5,216,107,279,68,3,869,10,32,8,142,13,121,175,27,26,6,349,27,6,125,6,83,14,4,62,2,2,9,7,9,92,6,23,408,7,111,216,79,80,20,37,695,2,75,17,15,245,62,6,1,89,5,84,16,44,3,1,1,23,73,136,63,12,127,375,7,8,8,424,93,44,128,363,101,132,89,88,63,2,12,7,346,2,100,34,30,96,172,4,13,61,6,122,127,3,11,0,14,7,5,110,18,219,205,21,13,142,43,55,42,152,33,669,145,6,25,125,3,553,119,67,37,6,54,37,9,72,19,134,4,8,21,24,170],"type":"bar"},{"x":["sensitive","demonstrate","applications","identified","stability","requested","overlapping","application","typicality","structure","satisf ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8216666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dataflow</span> <span style=''>Matrix</span> <span style=''>Machines</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.38317757009345793);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Dataflow</span> <span style=''>matrix</span> <span style=''>machines</span> <span style=''>are</span> <span style=''>a</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.38317757009345793);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>They</span> <span style=''>work</span> <span style=''>with</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>linear</span> <span style=''>streams</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>of</span> <span style=''>powerful</span> <span style=''>neurons</span> <span style=''>and</span> <span style=''>allow</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporate</span> <span style=''>higher</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructions</span> <span style=''>We</span> <span style=''>expect</span> <span style=''>them</span> <span style=''>to</span> <span style=''>be</span> <span style=''>useful</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.4431818181818182);'>programming</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7254901960784312);'>synthesis</span> <span style=''>of</span> <span style=''>dynamic</span> <span style=''>systems</span> <span style=''>and</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>programs</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>Multi</span> <span style=''>Output</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>for</span> <span style=''>Medical</span> <span style=''>Time</span> <span style=''>Series</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>In</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style=''>of</span> <span style=''>hospital</span> <span style=''>patients</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>patients</span> <span style=''>health</span> <span style=''>status</span> <span style=''>using</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>from</span> <span style=''>clinical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>and</span> <span style=''>lab</span> <span style=''>tests</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>to</span> <span style=''>enable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>medical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interventions</span> <span style=''>and</span> <span style=''>improve</span> <span style=''>patient</span> <span style=''>outcomes</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>and</span> <span style=''>explore</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>model</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>for</span> <span style=''>hospital</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>MedGP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>24</span> <span style=''>clinical</span> <span style=''>and</span> <span style=''>lab</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>and</span> <span style=''>supports</span> <span style=''>a</span> <span style=''>rich</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style=''>data</span> <span style=''>set</span> <span style=''>from</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>these</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariates</span> <span style=''>may</span> <span style=''>be</span> <span style=''>inferred</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploited</span> <span style=''>for</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>patient</span> <span style=''>state</span> <span style=''>over</span> <span style=''>time</span> <span style=''>To</span> <span style=''>do</span> <span style=''>this</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Geometry</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Graphical</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Hidden</span> <span style='background-color:rgba(255, 0, 0, 0.35999999999999993);'>Variables</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615383);'>likelihood</span> <span style=''>of</span> <span style=''>the</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>class</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>directed</span> <span style=''>graphs</span> <span style=''>with</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.35999999999999993);'>variables</span> <span style=''>This</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>before</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.5182481751824819);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>employed</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>certain</span> <span style=''>insights</span> <span style=''>in</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>unidentifiability</span> <span style=''>inherent</span> <span style=''>in</span> <span style=''>such</span> <span style=''>models</span> <span style=''>the</span> <span style=''>way</span> <span style='background-color:rgba(255, 0, 0, 0.5763546798029557);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.5625);'>densities</span> <span style=''>will</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.5625);'>densities</span> <span style=''>and</span> <span style=''>the</span> <span style=''>typical</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>geometrical</span> <span style=''>form</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.5763546798029557);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.5625);'>densities</span> <span style=''>might</span> <span style=''>take</span> <span style=''>Many</span> <span style=''>of</span> <span style=''>these</span> <span style=''>insights</span> <span style=''>carry</span> <span style=''>over</span> <span style=''>into</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematic</span> <span style=''>missing</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Actively</span> <span style=''>Learning</span> <span style=''>what</span> <span style=''>makes</span> <span style=''>a</span> <span style=''>Discrete</span> <span style=''>Sequence</span> <span style=''>Valid</span> <br/><br/><span style=''>Deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>have</span> <span style=''>been</span> <span style=''>hugely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>large</span> <span style=''>part</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>solve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>Recently</span> <span style=''>however</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>search</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>discrete</span> <span style=''>spaces</span> <span style=''>These</span> <span style=''>methods</span> <span style=''>work</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>discrete</span> <span style=''>objects</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>for</span> <span style=''>which</span> <span style=''>powerful</span> <span style=''>sequence</span> <span style=''>based</span> <span style=''>deep</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style=''>employed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>hindered</span> <span style=''>by</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>often</span> <span style=''>produce</span> <span style=''>invalid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>As</span> <span style=''>a</span> <span style=''>step</span> <span style=''>towards</span> <span style=''>solving</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>validator</span> <span style=''>model</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>partial</span> <span style=''>sequence</span> <span style=''>our</span> <span style=''>model</span> <span style=''>learns</span> <span style=''>the</span> <span style='background-c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10150107219442459)
# 	information (0.23909935668334525)
# 	automatic (0.07326661901358113)
# 	knowledge (0.134024303073624)
# 	different (0.2483917083631165)
# 	experimental (0.14581844174410294)
# 	segmentation (0.07719799857040743)
# 	detection (0.12473195139385275)
# 	convolutional (0.1322373123659757)
# 	recognition (0.13581129378127232)
#
# Some Statistics words are:
# 	variables (0.12737262737262736)
# 	stochastic (0.13686313686313686)
# 	theoretical (0.14985014985014986)
# 	statistical (0.15634365634365635)
# 	estimation (0.17832167832167833)
# 	algorithm (0.3916083916083916)
# 	distribution (0.1863136863136863)
# 	inference (0.2007992007992008)
# 	dimensional (0.1983016983016983)
# 	regression (0.17482517482517482)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cfd0ea3c-cd90-4a6b-bff1-86618b550752" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfd0ea3c-cd90-4a6b-bff1-86618b550752")) {                    Plotly.newPlot(                        "cfd0ea3c-cd90-4a6b-bff1-86618b550752",                        [{"x":["sensitive","demonstrate","applications","identified","stability","requested","overlapping","application","typicality","structure","satisfaction","potentially","understand","operations","platforms","permissions","factorization","suggesting","indicative","reputation","permission","simplifying","empirically","increased","unbounded","relaxation","inference","objective","posteriori","optimality","introduce","optimizing","theoretically","instances","variational","reweighted","conditional","algorithms","gradients","algorithm","synthetic","convergent","consistency","artificial","multiscale","experiments","hypothesis","relationships","confidence","directions","important","probability","variables","bootstrap","asymptotic","reliability","structural","computing","procedure","conducted","statistical","continuous","formulate","identification","assumption","inability","segmentation","conventional","effective","propagation","retrieves","performance","propagate","iteratively","displacement","challenge","continuity","mechanism","specifically","correspond","temporally","synthesizes","detection","adaptively","multiagent","reinforcement","distinguishes","sequential","cooperative","opponents","evolution","exploitative","prisoners","aforementioned","cooperate","cooperation","strategies","reflecting","exploited","experimental","gathering","sequences","effectiveness","demonstrated","characteristics","investigates","representative","different","passively","collected","opportunities","formalize","prediction","contextual","accompanied","retweeting","experiment","normative","following","aggregating","experience","adversely","followers","communitys","stationary","representing","comparison","containing","declarative","programming","knowledge","generators","abductive","substitution","approaches","semantics","combinatorial","solutions","representation","constraint","parameter","regularization","uncertainty","perspective","practitioner","operational","propagates","optimization","pessimistic","generalization","depending","reasonable","associated","theoretical","optimistic","practitioners","predictive","wasserstein","convergence","generative","penalizes","enforcing","invention","deviation","preferable","lipschitz","adversarial","supported","distribution","functions","arguments","augmenting","empirical","established","transform","denoising","therefore","perception","information","similarity","transfers","perceptual","promising","arrangement","framework","extracted","invariant","similarities","instability","differences","descriptions","qualities","connected","prominent","resulting","skeletons","curvature","viewpoint","smoothing","traditional","properties","recognition","successful","increasing","coordinate","topologies","corroborate","efficient","estimator","conditions","advocates","recursive","implicitly","identifiable","leveraging","measurable","infectious","underlying","unobservable","dependent","regularized","interestingly","advocated","timestamps","developed","numerical","competitive","resonance","biomarkers","motivating","extraction","posterior","improving","classification","conditioned","estimates","schizophrenia","psychiatric","disorders","unsupervised","extracting","regression","multilayer","dimensional","functional","extractors","presenting","perceptron","techniques","treatments","diagnoses","biological","investigation","development","encountered","diagnosis","generalized","replicates","interfa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	invention
# 	advocated
# 	timestamps
# 	schizophrenia
# 	psychiatric
# 	cybersecurity
# 	minimizers
# 	memberships
# 	censoring
# 	intentionally
# 	ensembling
# 	concordance
# 	tremendously
# 	looseness
# 	genuinely
# 	amortization
# 	inversions
# 	sparsification
# 	diagonalise
# 	customization
# Some words which never appear in Statistics papers:
# 	requested
# 	typicality
# 	permissions
# 	reputation
# 	permission
# 	displacement
# 	prisoners
# 	declarative
# 	skeletons
# 	interleaved
# 	propositional
# 	satisfiability
# 	suggestion
# 	outputting
# 	storytelling
# 	conversational
# 	strengthening
# 	interviews
# 	facilities
# 	spontaneous

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0729518775735975e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
